# %% [markdown]
# # jupyter notebook 示例

# %%
msg = "hey, you!!!"
print(msg)
# Out:
# hey, you!!!

# %%
import pandas as pd
import numpy as np

data = pd.Series(np.arange(5), list("abcde"))

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

mu = 100
sigma = 15
x = mu + sigma * np.random.randn(10000)
num_bins = 50

n, bins, patchs = plt.hist(x, num_bins, density=1, stacked=True, facecolor='blue', alpha=0.5)
y = norm.pdf(bins, mu, sigma)

plt.plot(bins, y, "r--")
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'Histogram of IQ: $\mu=100$,$sigma=15$')
plt.subplots_adjust(left=0.15)

plt.show()
